# %% [markdown]
# # Strings - Execrise

# %%
text = """The University of Hawaii began using radio to send digital information as early as 1971,using ALOHAnet. 
Friedhelm Hillebrand conceptualised SMS in 1984 while working for Deutsche Telekom. Sitting at a typewriter at home, 
Hillebrand typed out random sentences and counted every letter, number, punctuation, and space. 
Almost every time, the messages contained fewer than 160 characters, thus giving the basis for the 
limit one could type via text messaging. With Bernard Ghillebaert of France Télécom, he developed 
a proposal for the GSM (Groupe Spécial Mobile) meeting in February 1985 in Oslo. 
The first technical solution evolved in a GSM subgroup under the leadership of Finn Trosby. 
It was further developed under the leadership of Kevin Holley and Ian Harris (see Short Message Service). 
SMS forms an integral part of SS7 (Signalling System No. 7). Under SS7, it is a "state" with a 160 character data, 
coded in the ITU-T "T.56" text format, that has a "sequence lead in" to determine different language codes, 
and may have special character codes that permits, for example, sending simple graphs as text. 
This was part of ISDN (Integrated Services Digital Network) and since GSM is based on this, 
made its way to the mobile phone. Messages could be sent and received on ISDN phones, 
and these can send SMS to any GSM phone. The possibility of doing something is one thing, 
implementing it another, but systems existed from 1988 that sent SMS messages to mobile phones (compare ND-NOTIS)."""

# %% [markdown]
# > How many characters in text

# %%
# CODE HERE
count_chr = 0
for chr in text:
    count_chr += 1
print(count_chr)
# Out:
# 1507

# %% [markdown]
# > How many words are there in the "text"

# %%
# CODE HERE
print(len(text.split()))
# Out:
# 244

# %%
len(text.split())
# Out:
# 244

# %% [markdown]
# > How many unique words in the "text"

# %%
# CODE HERE
count_unique_words = 0
for i in text.split():
    for j in i:
        if j != i:
            count_unique_words += 1
print(count_unique_words)
# Out:
# 1244

# %% [markdown]
# > Find Lexical diversity
#
# lexical_diversity = (number of words)/(number of unique words)

# %% [markdown]
# > Count how many "the" in text

# %%
# CODE HERE
print(text.count("the"))
# Out:
# 11

# %% [markdown]
# > Count how many "a" in text

# %% [markdown]
# > Extract First 10 words in text

# %%
# CODE HERE
words = text.split()
for i in range(10):
    print(words[i])
# Out:
# The
# University
# of
# Hawaii
# began
# using
# radio
# to
# send
# digital

# %% [markdown]
# > Append " Innomatics Technology Hub" in first 10 words

# %%
# CODE HERE
words = text.split()
words.insert(10, "Innomatics Technology Hub")
text = " ".join(words)

# %% [markdown]
# > Extract First Fourteen (14) character in text

# %%
# CODE HERE
words = text.split()
for i in range(14):
    print(words[i])
# Out:
# The
# University
# of
# Hawaii
# began
# using
# radio
# to
# send
# digital
# Innomatics
# Technology
# Hub
# information

# %% [markdown]
# > Extract first Fourteen (14) words in text

# %%
# CODE HERE
words = text.split()
for i in range(14):
    print(words[i])
# Out:
# The
# University
# of
# Hawaii
# began
# using
# radio
# to
# send
# digital
# Innomatics
# Technology
# Hub
# information

# %% [markdown]
# > Extract First 10 words in text
# - Convert every letter into ***upper*** case
# - Convert every letter into ***lower*** case

# %%
# CODE HERE
words = text.split()
for i in range(10):
    print(words[i].upper())
# Out:
# THE
# UNIVERSITY
# OF
# HAWAII
# BEGAN
# USING
# RADIO
# TO
# SEND
# DIGITAL

# %%
# CODE HERE
for i in range(10):
    print(words[i].lower())
# Out:
# the
# university
# of
# hawaii
# began
# using
# radio
# to
# send
# digital

# %% [markdown]
# > Find the list of letter starting with
# - u
# - o

# %%
# CODE HERE
for i in words:
    if i[0].lower() == "u":
        print(i)

for i in words:
    if i[0].lower() == "o":
        print(i)
# Out:
# University
# using
# under
# under
# Under
# of
# out
# one
# of
# Oslo.
# of
# of
# of
# of
# on
# on
# of
# one

# %% [markdown]
# > Find the list of letter ending with
# - e
# - n

# %%
# CODE HERE
for i in words:
    if i[-1].lower() == "e":
        print(i)

for i in words:
    if i[-1].lower() == "n":
        print(i)
# Out:
# The
# while
# Deutsche
# the
# the
# the
# one
# type
# France
# he
# the
# (Groupe
# The
# the
# the
# (see
# Message
# the
# "sequence
# determine
# language
# have
# simple
# since
# made
# the
# mobile
# be
# these
# The
# one
# mobile
# (compare
# began
# information
# in
# than
# in
# in
# solution
# in
# Finn
# Kevin
# Ian
# an
# in
# ISDN
# on
# on
# ISDN
# can

# %% [markdown]
# > Extract first 10 words of text and Capitalize first letter of each word

# %%
# CODE HERE
for i in range(10):
    print(words[i].capitalize())
# Out:
# The
# University
# Of
# Hawaii
# Began
# Using
# Radio
# To
# Send
# Digital

# %% [markdown]
# > Replace the word "University" with name "Innomatics" in text

# %%
# CODE HERE
text = text.replace("University", "Innomatics")

# %% [markdown]
# ## Convert the "text" into sentances and store that into sentance

# %%
# CODE HERE
sentence = text.split('. ')
sentence = [s for s in sentence if s]
# print(sentence)
# Out:
# ['The Innomatics of Hawaii began using radio to send digital Innomatics Technology Hub information as early as 1971,using ALOHAnet', 'Friedhelm Hillebrand conceptualised SMS in 1984 while working for Deutsche Telekom', 'Sitting at a typewriter at home, Hillebrand typed out random sentences and counted every letter, number, punctuation, and space', 'Almost every time, the messages contained fewer than 160 characters, thus giving the basis for the limit one could type via text messaging', 'With Bernard Ghillebaert of France Télécom, he developed a proposal for the GSM (Groupe Spécial Mobile) meeting in February 1985 in Oslo', 'The first technical solution evolved in a GSM subgroup under the leadership of Finn Trosby', 'It was further developed under the leadership of Kevin Holley and Ian Harris (see Short Message Service)', 'SMS forms an integral part of SS7 (Signalling System No', '7)', 'Under SS7, it is a "state" with a 160 character data, coded in the ITU-T "T.56" text format, that has a "sequence lead in" to determine different language codes, and may have special character codes that permits, for example, sending simple graphs as text', 'This was part of ISDN (Integrated Services Digital Network) and since GSM is based on this, made its way to the mobile phone', 'Messages could be sent and received on ISDN phones, and these can send SMS to any GSM phone', 'The possibility of doing something is one thing, implementing it another, but systems existed from 1988 that sent SMS messages to mobile phones (compare ND-NOTIS).']

# %% [markdown]
# ### 1.From the above sentance remove '\n'
# ### 2. From the above sentace print the first word from each sentance
# ### 3. From the above sentace print even posioned sentances

# %%
sentence = [s.replace('\n', ' ').strip() for s in sentence if s.strip()]
for s in sentence:
    words = s.split()
    if words:
        print(words[0])
# Out:
# The
# Friedhelm
# Sitting
# Almost
# With
# The
# It
# SMS
# 7)
# Under
# This
# Messages
# The

# %%
print(sentence)
for i in range(1, len(sentence),):
    print(f"Position {i}: {sentence[i]}")
# Out:
# ['The Innomatics of Hawaii began using radio to send digital Innomatics Technology Hub information as early as 1971,using ALOHAnet', 'Friedhelm Hillebrand conceptualised SMS in 1984 while working for Deutsche Telekom', 'Sitting at a typewriter at home, Hillebrand typed out random sentences and counted every letter, number, punctuation, and space', 'Almost every time, the messages contained fewer than 160 characters, thus giving the basis for the limit one could type via text messaging', 'With Bernard Ghillebaert of France Télécom, he developed a proposal for the GSM (Groupe Spécial Mobile) meeting in February 1985 in Oslo', 'The first technical solution evolved in a GSM subgroup under the leadership of Finn Trosby', 'It was further developed under the leadership of Kevin Holley and Ian Harris (see Short Message Service)', 'SMS forms an integral part of SS7 (Signalling System No', '7)', 'Under SS7, it is a "state" with a 160 character data, coded in the ITU-T "T.56" text format, that has a "sequence lead in" to determine different language codes, and may have special character codes that permits, for example, sending simple graphs as text', 'This was part of ISDN (Integrated Services Digital Network) and since GSM is based on this, made its way to the mobile phone', 'Messages could be sent and received on ISDN phones, and these can send SMS to any GSM phone', 'The possibility of doing something is one thing, implementing it another, but systems existed from 1988 that sent SMS messages to mobile phones (compare ND-NOTIS).']
# Position 1: Friedhelm Hillebrand conceptualised SMS in 1984 while working for Deutsche Telekom
# Position 2: Sitting at a typewriter at home, Hillebrand typed out random sentences and counted every letter, number, punctuation, and space
# Position 3: Almost every time, the messages contained fewer than 160 characters, thus giving the basis for the limit one could type via text messaging
# Position 4: With Bernard Ghillebaert of France Télécom, he developed a proposal for the GSM (Groupe Spécial Mobile) meeting in February 1985 in Oslo
# Position 5: The first technical solution evolved in a GSM subgroup under the leadership of Finn Trosby
# Position 6: It was further developed under the leadership of Kevin Holley and Ian Harris (see Short Message Service)
# Position 7: SMS forms an integral part of SS7 (Signalling System No
# Position 8: 7)
# Position 9: Under SS7, it is a "state" with a 160 character data, coded in the ITU-T "T.56" text format, that has a "sequence lead in" to determine different language codes, and may have special character codes that permits, for example, sending simple graphs as text
# Position 10: This was part of ISDN (Integrated Services Digital Network) and since GSM is based on this, made its way to the mobile phone
# Position 11: Messages could be sent and received on ISDN phones, and these can send SMS to any GSM phone
# Position 12: The possibility of doing something is one thing, implementing it another, but systems existed from 1988 that sent SMS messages to mobile phones (compare ND-NOTIS).

# %% [markdown]
# ### If the following string is given as input to the program:
#
# - H1e2l3l4o5w6o7r8l9d
#
# ### Then, the output of the program should be:
#
# - Helloworld

# %%
# CODE HERE
string = input("Enter a string: ")
temp_list = []
for i in string:
    if i.isalpha():
        temp_list.append(i)
result = "".join(temp_list)
print(result)
# Out:
# Helloworld

# %% [markdown]
# # [Innomatics Research Labs](https:/innomatics.in/)
# [www.innomatics.in](https:/innomatics.in/)
